# %%
import pandas as pd
import os
import shutil

# %%
year = 2021

norm_ranges = list(range(2, 31))
PSO_ranges = list(range(5, 75, 5))

# %%
directory = 'norm_PSO_combination_' + str(year)
fnished_folders = os.listdir(directory)
folders = [i for i in fnished_folders if '_PSO_' in i]

# %%
len(folders)
# Out:
# 406

# %%
def process_one_combination(combination):
    norm_here = combination.split('_')[1]
    PSO_range_here = combination.split('_')[-1]
    path_here = directory + '/' + combination + '/PSO_' + str(year) + '_6params_NYC_' + combination + '.csv'
    dest_dire = 'data/3_PSO_results/PSO_calirabtion_results/'
    copied_dire =  dest_dire + 'norm_PSO_combination_'+str(year) + '/' + 'PSO_' + str(
        year) + '_6params_NYC_' + combination + '.csv'
    shutil.copy(path_here, copied_dire)
    
    df_temp = pd.read_csv(path_here)
    if df_temp.shape[0] != 6493 or df_temp['cbg'].nunique() != 6493:
        print(combination, '?')
    df_temp = df_temp[df_temp['cost'] != 'no visitors']
    df_temp['cost'] = df_temp['cost'].astype(float)
    return int(norm_here), int(PSO_range_here), df_temp['cost'].mean(), df_temp['cost'].median()

# %%
error_stats = {'norm': [], 'PSO_range': [], 'mean': [], 'median': []}

for indx, f in enumerate(folders):
    values_here = process_one_combination(f)
    error_stats['norm'].append(values_here[0])
    error_stats['PSO_range'].append(values_here[1])
    error_stats['mean'].append(values_here[2])
    error_stats['median'].append(values_here[3])
    if (indx+1) % 40 == 0:
        print("{:.2%}".format((indx+1)/len(folders)), ' finished')
# Out:
# 9.85%  finished
# 19.70%  finished
# 29.56%  finished
# 39.41%  finished
# 49.26%  finished
# 59.11%  finished
# 68.97%  finished
# 78.82%  finished
# 88.67%  finished
# 98.52%  finished

# %%
error_stats_df = pd.DataFrame(error_stats).sort_values(by = ['norm', 'PSO_range'])
error_stats_df
# Out:
#      norm  PSO_range      mean    median
# 165     2          5  0.536655  0.547226
# 142     2         10  0.428957  0.436659
# 319     2         15  0.381886  0.378768
# 117     2         20  0.359215  0.347253
# 344     2         25  0.346621  0.323784
# ..    ...        ...       ...       ...
# 294    30         50  0.338444  0.289624
# 66     30         55  0.340605  0.293374
# 269    30         60  0.342387  0.296035
# 92     30         65  0.344452  0.299499
# 150    30         70  0.344265  0.296929
#
# [406 rows x 4 columns]

# %%
error_stats_matrix_mean = {}
error_stats_matrix_median = {}

for n in norm_ranges:
    error_stats_matrix_mean[n] = {}
    error_stats_matrix_median[n] = {}

for indx, cont in error_stats_df.iterrows():
    error_stats_matrix_mean[cont['norm']][int(cont['PSO_range'])] = cont['mean']
    error_stats_matrix_median[cont['norm']][int(cont['PSO_range'])] = cont['median']

# %%
error_stats_matrix_mean_df = pd.DataFrame(error_stats_matrix_mean).T
error_stats_matrix_mean_df
# Out:
#           5         10        15        20        25        30        35  \
# 2   0.536655  0.428957  0.381886  0.359215  0.346621  0.341311  0.338509
# 3   0.451898  0.365909  0.341296  0.330968  0.329562  0.329726  0.331713
# 4   0.411107  0.344241  0.328230  0.326604  0.326289  0.329896  0.331675
# 5   0.389050  0.334621  0.323563  0.322600  0.325399  0.328816  0.333063
# 6   0.375208  0.329511  0.321087  0.323990  0.326219  0.329710  0.332991
# 7   0.365735  0.327693  0.321137  0.323081  0.327470  0.330050  0.334585
# 8   0.359939  0.323577  0.319681  0.323442  0.325418  0.331103  0.334243
# 9   0.355330  0.322588  0.320322  0.323430  0.327224  0.330859  0.333745
# 10  0.352128  0.321300  0.319846  0.325208  0.327507  0.329544  0.333296
# 11  0.348256  0.321471  0.320048  0.323698  0.326968  0.330677  0.334411
# 12  0.347024  0.320503  0.319247  0.324867  0.327820  0.331555  0.334724
# 13  0.344968  0.320847  0.321909  0.324122  0.329201  0.329373  0.334017
# ...

# %%
error_stats_matrix_median_df = pd.DataFrame(error_stats_matrix_median).T
error_stats_matrix_median_df
# Out:
#           5         10        15        20        25        30        35  \
# 2   0.547226  0.436659  0.378768  0.347253  0.323784  0.310079  0.301963
# 3   0.460994  0.354576  0.312616  0.293549  0.286035  0.281387  0.283138
# 4   0.413403  0.319106  0.287578  0.279462  0.274532  0.277179  0.277286
# 5   0.383602  0.301434  0.279748  0.276668  0.272852  0.271925  0.279069
# 6   0.362774  0.292070  0.275018  0.274830  0.272011  0.273616  0.276910
# 7   0.348363  0.287952  0.271281  0.270605  0.273145  0.273604  0.279725
# 8   0.338192  0.280399  0.269904  0.272196  0.272390  0.274069  0.280616
# 9   0.331615  0.279303  0.266684  0.270263  0.272287  0.276637  0.279686
# 10  0.325068  0.273740  0.266821  0.270355  0.272813  0.275347  0.277879
# 11  0.319103  0.273436  0.264872  0.267788  0.271384  0.274660  0.278107
# 12  0.317404  0.270884  0.266039  0.270987  0.271242  0.275997  0.281558
# 13  0.312747  0.269529  0.265553  0.267268  0.275778  0.273480  0.281342
# ...

# %%
error_stats_matrix_mean_df.to_csv(
    'data/3_PSO_results/norm_PSO_simulated_annealing_data/norm_PSO_error_means_'+str(
        year)+'.csv')

# %%
error_stats_matrix_median_df.to_csv(
    'data/3_PSO_results/norm_PSO_simulated_annealing_data/norm_PSO_error_medians_'+str(
        year)+ '.csv')
